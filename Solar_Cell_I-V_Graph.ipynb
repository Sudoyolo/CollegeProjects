# %% [markdown]
# <a href="https://colab.research.google.com/github/Sudoyolo/CollegeProjects/blob/main/Solar_Cell_I-V_Graph.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import math
import matplotlib.pyplot as plt

# %%
# Voltage
V = np.linspace(-1,1)

# %%
# Saturation Current I0
I0 = 1.8 * math.pow(10,-12)

# %%
# Elementary (Electronic) Charge
q = 1.60217662 * math.pow(10,-19)

# %%
# Boltzmann's Constant
kB = 1.38064852 * math.pow(10,-23)

# %%
# Ideality Factor 
n = 1

# %%
# Temperature 
T = 298.15

# %%
# Light generated current
IL1 = 0
IL2 = 0.5
IL3 = 1
IL4 = 1.5
IL5 = 2
IL6 = 2.5

# %%
# Shockley Equation
I = I0 * (np.exp((V*q)/(kB*T)) - 1) - IL

# %%
# Plotting the curves individually
I1 = I = I0 * (np.exp((V*q)/(kB*T)) - 1) - IL1
plt.plot(V, I1, color='r')
plt.xlabel("Voltage")
plt.ylabel("Current")
plt.title("I-V Characcteristics of a Solar Cell at IL = 0")
plt.show()

I2 = I = I0 * (np.exp((V*q)/(kB*T)) - 1) - IL2
plt.plot(V, I2, color='g')
plt.xlabel("Voltage")
plt.ylabel("Current")
plt.title("I-V Characcteristics of a Solar Cell at IL = 0.5")
plt.show()

I3 = I = I0 * (np.exp((V*q)/(kB*T)) - 1) - IL3
plt.plot(V, I3, color='b')
plt.xlabel("Voltage")
plt.ylabel("Current")
plt.title("I-V Characcteristics of a Solar Cell at IL = 1")
plt.show()

I4 = I = I0 * (np.exp((V*q)/(kB*T)) - 1) - IL4
plt.plot(V, I4, color='y')
plt.xlabel("Voltage")
plt.ylabel("Current")
plt.title("I-V Characcteristics of a Solar Cell at IL = 1.5")
plt.show()

I5 = I = I0 * (np.exp((V*q)/(kB*T)) - 1) - IL5
plt.plot(V, I5, color='c')
plt.xlabel("Voltage")
plt.ylabel("Current")
plt.title("I-V Characcteristics of a Solar Cell at IL = 2")
plt.show()

I6 = I = I0 * (np.exp((V*q)/(kB*T)) - 1) - IL6
plt.plot(V, I6, color='m')
plt.xlabel("Voltage")
plt.ylabel("Current")
plt.title("I-V Characcteristics of a Solar Cell at IL = 2.5")
plt.show()

# %%
# Plotting the curves simultaneously
I1 = I = I0 * (np.exp((V*q)/(kB*T)) - 1) - IL1
I2 = I = I0 * (np.exp((V*q)/(kB*T)) - 1) - IL2
I3 = I = I0 * (np.exp((V*q)/(kB*T)) - 1) - IL3
I4 = I = I0 * (np.exp((V*q)/(kB*T)) - 1) - IL4
I5 = I = I0 * (np.exp((V*q)/(kB*T)) - 1) - IL5
I6 = I = I0 * (np.exp((V*q)/(kB*T)) - 1) - IL6

plt.plot(V, I1, color='r', label='IL = 0')
plt.plot(V, I2, color='g', label='IL = 0.5')
plt.plot(V, I3, color='b', label='IL = 1')
plt.plot(V, I4, color='y', label='IL = 1.5')
plt.plot(V, I5, color='c', label='IL = 2')
plt.plot(V, I6, color='m', label='IL = 2.5')
  
# Naming the x-axis, y-axis and the whole graph
plt.xlabel("Voltage")
plt.ylabel("Current")
plt.title("I-V Characcteristics of a Solar Cell")
  
# Adding legend, which helps us recognize the curve according to it's color
plt.legend()
  
# To load the display window
plt.show()
